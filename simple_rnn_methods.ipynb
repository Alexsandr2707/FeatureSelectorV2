# %% [markdown]
# # **Эксперименты с простым RNN**

# %% [markdown]
# ## Сырые данные

# %% [markdown]
# Конфиг: [data_configs/base_raw_data.py](data_configs/base_raw_data.py)
# Описание: сырые данные с отбором признаков при помощи pls регрессии с pls_depth=3
# Полученные метрики (см. ниже под графиком)

# %%
# %reset -f
# %matplotlib inline

import exp
import data_configs.base_raw_data as config_module

exec_config = config_module.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(exec_config=exec_config, make_plot_prep_data=False, make_plot_results=True)
print(results)
# Out:
# MAE                  2.351675
# rMSE                 3.397601
# MAPE                 0.006390
# Pearson (p-value)    0.000121
# Pearson              0.404971
# R2                   0.094912
# Hinge                0.453296
# dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# ## Custom сырые данные

# %% [markdown]
# Конфиг: [data_configs/custom_data_config.py](data_configs/custom_data_config.py)
# Описание: сырые данные с отбором признаков при помощи pls регрессии с pls_depth=2
# Полученные метрики: (см. ниже)

# %%
# %reset -f
# %matplotlib inline

import exp
import data_configs.custom_data_config as config_module

exec_config = config_module.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(exec_config=exec_config, make_plot_prep_data=False, make_plot_results=True)
print(results)
# Out:
# MAE                  2.336735e+00
# rMSE                 3.086770e+00
# MAPE                 6.336968e-03
# Pearson (p-value)    5.932605e-07
# Pearson              5.106801e-01
# R2                   2.529418e-01
# Hinge                3.827967e-01
# dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# ## Spline-interpolation

# %% [markdown]
# Конфиг: [data_configs/base_interp_data.py](data_configs/base_interp_data.py)
# Описание: данные с spline-интрерполяцией и отбором признаков при помощи pls регрессии с pls_depth=3
# Полученные метрики: (см. ниже)

# %%
# %reset -f
# %matplotlib inline

import exp
import data_configs.base_interp_data as config_module

exec_config = config_module.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(exec_config=exec_config, make_plot_prep_data=False, make_plot_results=True)
print(results)
# Out:
# MAE                  2.323050e+00
# rMSE                 3.349386e+00
# MAPE                 6.311728e-03
# Pearson (p-value)    2.333020e-49
# Pearson              2.581550e-01
# R2                   2.685446e-02
# Hinge                4.794346e-01
# dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# ## Custom-Spline-interpolation

# %% [markdown]
# Конфиг: [data_configs/custom_loess_data_config.py](data_configs/custom_loess_data_config.py)
# Описание: данные с spline-интрерполяцией, сглаживанием и отбором признаков при помощи pls регрессии с pls_depth=3
# Полученные метрики: (см. ниже)

# %%
# %reset -f
# %matplotlib inline

import exp
import data_configs.custom_interp_data_config as config_module

exec_config = config_module.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(exec_config=exec_config, make_plot_prep_data=False, make_plot_results=True)
print(results)
# Out:
# MAE                  2.237683e+00
# rMSE                 3.264025e+00
# MAPE                 6.075491e-03
# Pearson (p-value)    2.879138e-67
# Pearson              3.004195e-01
# R2                   9.978354e-03
# Hinge                4.610150e-01
# dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# ## Custom-loess-interpolation

# %% [markdown]
# Конфиг: [data_configs/base_interp_data.py](data_configs/base_interp_data.py)
# Описание: данные с loess-интрерполяцией (линейная интреполяция + loess сглаживание) и отбором признаков при помощи pls регрессии с pls_depth=3
# Полученные метрики: (см. ниже)

# %%
# %reset -f
# %matplotlib inline

import exp
import data_configs.custom_loess_data_config as config_module

exec_config = config_module.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(exec_config=exec_config, make_plot_prep_data=False, make_plot_results=True)
print(results)
# Out:
# MAE                  1.869376e+00
# rMSE                 2.748901e+00
# MAPE                 5.070927e-03
# Pearson (p-value)    8.319275e-71
# Pearson              3.086069e-01
# R2                   8.106267e-02
# Hinge                2.946169e-01
# dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# ## Custom-knn-interpolation

# %% [markdown]
# Конфиг: [data_configs/custom_knn_data_config.py](data_configs/custom_knn_data_config.py)
# Описание: данные с knn-интрерполяцией, сглаживанием и отбором признаков при помощи pls регрессии с pls_depth=3
# Полученные метрики: (см. ниже)

# %%
# %reset -f
# %matplotlib inline

import exp
import data_configs.custom_knn_data_config as config_module

exec_config = config_module.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(exec_config=exec_config, make_plot_prep_data=False, make_plot_results=True)
print(results)
# Out:
# MAE                  1.999500e+00
# rMSE                 2.808878e+00
# MAPE                 5.408038e-03
# Pearson (p-value)    2.100219e-53
# Pearson              2.668186e-01
# R2                  -9.484577e-02
# Hinge                3.170923e-01
# dtype: float64
