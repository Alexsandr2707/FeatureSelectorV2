# %% [markdown]
# ## Bayes feature selection

# %% [markdown]
# Выбранные признаки
# '81TI10124', '81TI10127', '81TI10130', '81LILH40011', '81PC20310', '81PI20323', '81TIHHH18001', '81PI20320', '81TIH12412', '81TI10143', '81LZLLHH40001A1', '81TI10128', '81TC10119', '81TI10126', '81PZLLLH28001', '81PI20311'

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300 

import exp
import data_configs.feature_selection.bayes as config

exec_config = config.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(
    exec_config=exec_config, 
    make_plot_results=True, 
    make_plot_bn_tree=True, 
    make_plot_prep_data=True,
)
results = results.rename("Values")
md_results = results.to_markdown(floatfmt=".6f")
print(md_results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# [14-05-2026 06:19:39] [setgraphviz.setgraphviz] [INFO] The OS is not supported to automatically set Graphviz in the system env.
# [14-05-2026 06:19:39] [setgraphviz.setgraphviz] [INFO] Graphviz path found in environment.
# |                   |   Values |
# |:------------------|---------:|
# | MAE               | 2.372347 |
# | rMSE              | 3.449376 |
# | MAPE              | 0.006448 |
# | Pearson (p-value) | 0.005791 |
# | Pearson           | 0.296911 |
# | R2                | 0.067117 |
# | Hinge             | 0.498077 |

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300 

import exp
import data_configs.feature_selection.bayes as config

exec_config = config.EXECUTE_CONFIG
exp.setup_logging(root_only=True, console_level="WARNING")

seeds = (0, 10)
results, _ = exp.seeds_experiment(seeds=seeds, exec_config=exec_config)
metrics = exp.metrics_summary(results)
md_results = metrics.to_markdown(floatfmt=".6f")
print(md_results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/41905.0 [00:00<?, ?it/s]
# |                   |     mean |      std |    score |
# |:------------------|---------:|---------:|---------:|
# | MAE               | 2.415993 | 0.072526 | 2.452256 |
# | rMSE              | 3.519764 | 0.071633 | 3.555581 |
# | MAPE              | 0.006566 | 0.000198 | 0.006665 |
# ...

# %% [markdown]
# ## PLS fearure selection

# %% [markdown]
# Выбранные признаки
#
# "81TI10143",
# "81TI10126",
# "81FIL30066",
# "81LILH40012",
# "81TIH11209",
# "81FCL30063",
# "81FI30052",
# "81TI10123"

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300 

import exp
import data_configs.feature_selection.pls as config

exec_config = config.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(
    exec_config=exec_config, 
    make_plot_results=True, 
    make_plot_prep_data=True,
)
results = results.rename("Values")
md_results = results.to_markdown(floatfmt=".6f")
print(md_results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# |                   |   Values |
# |:------------------|---------:|
# | MAE               | 2.213336 |
# | rMSE              | 3.244272 |
# | MAPE              | 0.006008 |
# | Pearson (p-value) | 0.000038 |
# | Pearson           | 0.431250 |
# | R2                | 0.174760 |
# | Hinge             | 0.413477 |

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300 

import exp
import data_configs.feature_selection.pls as config

exec_config = config.EXECUTE_CONFIG
exp.setup_logging(root_only=True, console_level="WARNING")

seeds = (0, 10)
results, _ = exp.seeds_experiment(seeds=seeds, exec_config=exec_config)
metrics = exp.metrics_summary(results)
md_results = metrics.to_markdown(floatfmt=".6f")
print(md_results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# |                   |     mean |      std |    score |
# |:------------------|---------:|---------:|---------:|
# | MAE               | 2.263462 | 0.067399 | 2.297161 |
# | rMSE              | 3.325584 | 0.065834 | 3.358501 |
# | MAPE              | 0.006144 | 0.000179 | 0.006233 |
# | Pearson (p-value) | 0.000232 | 0.000161 | 0.000312 |
# | Pearson           | 0.396032 | 0.020109 | 0.385978 |
# | R2                | 0.132535 | 0.034526 | 0.115272 |
# | Hinge             | 0.435683 | 0.027927 | 0.449646 |

# %% [markdown]
# ## Lasso Selection

# %% [markdown]
# Выбранные признаки
# '81FI30055', '81FI30080', '81FI30079', '81FI30055.1', '81FCL30063', '81FCL30065', '81FCLH30072', '81FIL30066'

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300 

import exp
import data_configs.feature_selection.lasso as config

exec_config = config.EXECUTE_CONFIG
exp.setup_logging(root_only=False, console_level="WARNING")
results = exp.basic_experiment(
    exec_config=exec_config, 
    make_plot_results=True, 
    make_plot_bn_tree=True, 
    make_plot_prep_data=True,
)
results = results.rename("Values")
md_results = results.to_markdown(floatfmt=".6f")
print(md_results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# |                   |    Values |
# |:------------------|----------:|
# | MAE               |  3.089043 |
# | rMSE              |  4.716735 |
# | MAPE              |  0.008398 |
# | Pearson (p-value) |  0.110872 |
# | Pearson           |  0.174179 |
# | R2                | -0.744331 |
# | Hinge             |  1.010322 |

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300 

import exp
import data_configs.feature_selection.lasso as config

exec_config = config.EXECUTE_CONFIG
exp.setup_logging(root_only=True, console_level="WARNING")

seeds = (0, 10)
results, _ = exp.seeds_experiment(seeds=seeds, exec_config=exec_config)
metrics = exp.metrics_summary(results)
md_results = metrics.to_markdown(floatfmt=".6f")
print(md_results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# |                   |      mean |      std |     score |
# |:------------------|----------:|---------:|----------:|
# | MAE               |  3.412988 | 0.263515 |  3.544745 |
# | rMSE              |  5.054628 | 0.354021 |  5.231639 |
# | MAPE              |  0.009276 | 0.000714 |  0.009632 |
# | Pearson (p-value) |  0.182484 | 0.063118 |  0.214043 |
# | Pearson           |  0.149039 | 0.022797 |  0.137641 |
# | R2                | -1.013026 | 0.282333 | -1.154193 |
# | Hinge             |  1.182767 | 0.175103 |  1.270318 |
